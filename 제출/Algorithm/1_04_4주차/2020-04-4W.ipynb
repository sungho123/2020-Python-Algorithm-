# %%
input = [472, 385]
a = input[0]
b = str(input[1])[::-1]
ind = 1
mul = 0 
sum = 0

for n in b :
    mul = a * int(n)
    print( mul )
    mul *= ind
    ind *= 10
    sum += mul

print(sum)
# Out:
# 2360
# 3776
# 1416
# 181720

# %%
input2 = [10, 65, 100, 30, 95]
avg = 0
for grd in input2 :
    if grd <= 40 :
        grd = 40  
    avg += grd

print ( avg / len(input2) )
# Out:
# 68.0
